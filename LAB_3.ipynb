# %% [markdown]
# <a href="https://colab.research.google.com/github/KASAMSATHWIK/RL/blob/main/LAB_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# Part A - Machine Initialization
machines = ['A', 'B', 'C']
N_play = 10
epsilon = 0.2
N = {'A': 0, 'B': 0, 'C': 0}
R = {'A': [], 'B': [], 'C': []}
Q = {'A': 0.0, 'B': 0.0, 'C': 0.0}
total_reward = 0
print("Modified Epsilon-Greedy Multi-Armed Bandit")
print("------------------------------------------")
for play in range(1, N_play + 1):
    r = random.random()
    best_machine = max(Q, key=Q.get)
    if r < epsilon:
        other_machines = [m for m in machines if m != best_machine]
        selected_machine = random.choice(other_machines)
        print(f"\nPlay {play}: Exploration")
    else:
        selected_machine = best_machine
        print(f"\nPlay {play}: Exploitation")
    print("Selected Machine:", selected_machine)
    reward = float(input(f"Enter reward for machine {selected_machine}: "))
    N[selected_machine] += 1
    R[selected_machine].append(reward)
    Q[selected_machine] = Q[selected_machine] + (
        (reward - Q[selected_machine]) / N[selected_machine]
    )
    total_reward += reward
    print("Updated Q-values:", Q)
# Part F - Display Results
print("\n========== FINAL RESULTS ==========")
print("\nN Table - Participation Count")
for machine in machines:
    print(machine, ":", N[machine])
print("\nR Table - Rewards")
for machine in machines:
    print(machine, ":", R[machine])
print("\nQ Table - Estimated Values")
for machine in machines:
    print(machine, ":", round(Q[machine], 2))
print("\nTotal Reward Received:", total_reward)
# Out:
# Modified Epsilon-Greedy Multi-Armed Bandit
# ------------------------------------------
#
# Play 1: Exploitation
# Selected Machine: A
# Enter reward for machine A: 4
# Updated Q-values: {'A': 4.0, 'B': 0.0, 'C': 0.0}
#
# Play 2: Exploitation
# Selected Machine: A
# Enter reward for machine A: 7
# Updated Q-values: {'A': 5.5, 'B': 0.0, 'C': 0.0}
#
# Play 3: Exploitation
# Selected Machine: A
# Enter reward for machine A: 8
# Updated Q-values: {'A': 6.333333333333333, 'B': 0.0, 'C': 0.0}
#
# Play 4: Exploration
# Selected Machine: C
# Enter reward for machine C: 3
# Updated Q-values: {'A': 6.333333333333333, 'B': 0.0, 'C': 3.0}
#
# Play 5: Exploitation
# Selected Machine: A
# Enter reward for machine A: 8
# Updated Q-values: {'A': 6.75, 'B': 0.0, 'C': 3.0}
#
# Play 6: Exploitation
# Selected Machine: A
# Enter reward for machine A: 9
# Updated Q-values: {'A': 7.2, 'B': 0.0, 'C': 3.0}
#
# Play 7: Exploitation
# Selected Machine: A
# Enter reward for machine A: 1
# Updated Q-values: {'A': 6.166666666666667, 'B': 0.0, 'C': 3.0}
#
# Play 8: Exploration
# Selected Machine: B
# Enter reward for machine B: 2
# Updated Q-values: {'A': 6.166666666666667, 'B': 2.0, 'C': 3.0}
#
# Play 9: Exploration
# Selected Machine: C
# Enter reward for machine C: 1
# Updated Q-values: {'A': 6.166666666666667, 'B': 2.0, 'C': 2.0}
#
# Play 10: Exploitation
# Selected Machine: A
# Enter reward for machine A: 16
# Updated Q-values: {'A': 7.571428571428571, 'B': 2.0, 'C': 2.0}
#
# ========== FINAL RESULTS ==========
#
# N Table - Participation Count
# A : 7
# B : 1
# C : 2
#
# R Table - Rewards
# A : [4.0, 7.0, 8.0, 8.0, 9.0, 1.0, 16.0]
# B : [2.0]
# C : [3.0, 1.0]
#
# Q Table - Estimated Values
# A : 7.57
# B : 2.0
# C : 2.0
#
# Total Reward Received: 59.0
