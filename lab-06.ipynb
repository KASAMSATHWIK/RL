# %% [markdown]
# <a href="https://colab.research.google.com/github/KASAMSATHWIK/RL/blob/main/lab-06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gymnasium as gym

def random_agent(env_name, episodes=5):
    env = gym.make(env_name)

    for episode in range(1, episodes + 1):
        state, info = env.reset()
        total_reward = 0
        steps = 0
        terminated = False
        truncated = False

        while not (terminated or truncated):
            action = env.action_space.sample()
            next_state, reward, terminated, truncated, info = env.step(action)

            total_reward += reward
            steps += 1
            state = next_state

        average_reward = total_reward / steps

        print("Episode:", episode)
        print("Total Reward:", total_reward)
        print("Average Reward:", round(average_reward, 2))
        print()

    env.close()

print("CliffWalking Environment")
random_agent("CliffWalking-v1", 5)

print("Taxi Environment")
random_agent("Taxi-v4", 5)
# Out:
# CliffWalking Environment
# Episode: 1
# Total Reward: -33947
# Average Reward: -8.38
#
# Episode: 2
# Total Reward: -69848
# Average Reward: -11.28
#
# Episode: 3
# Total Reward: -215988
# Average Reward: -10.45
#
# Episode: 4
# Total Reward: -30724
# Average Reward: -10.95
#
# Episode: 5
# Total Reward: -30253
# Average Reward: -10.69
#
# Taxi Environment
# Episode: 1
# Total Reward: -911
# Average Reward: -4.55
#
# Episode: 2
# Total Reward: -821
# Average Reward: -4.11
#
# Episode: 3
# Total Reward: -785
# Average Reward: -3.92
#
# Episode: 4
# Total Reward: -288
# Average Reward: -3.84
#
# Episode: 5
# Total Reward: -722
# Average Reward: -3.61
